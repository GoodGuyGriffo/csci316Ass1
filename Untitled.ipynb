# %% [markdown]
# # CSCI316 Task 1- Mitchell Griffiths 6414801

# %% [markdown]
# ### Load in the data

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit

seed = 123
np.random.seed(seed)
rng = np.random.RandomState(seed)

# %%
df = pd.read_csv("train.csv")

# %% [markdown]
# ### Inspecting the data

# %%
df.head()
# Out:
#    number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                   4         88.944468             57.862692
# 1                   5         92.729214             58.518416
# 2                   4         88.944468             57.885242
# 3                   4         88.944468             57.873967
# 4                   4         88.944468             57.840143
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0          66.361592              36.116612             1.181795
# 1          73.132787              36.396602             1.449309
# 2          66.361592              36.122509             1.181795
# 3          66.361592              36.119560             1.181795
# 4          66.361592              36.110716             1.181795
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                 1.062396          122.90607              31.794921
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21263 entries, 0 to 21262
# Data columns (total 82 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   number_of_elements               21263 non-null  int64
#  1   mean_atomic_mass                 21263 non-null  float64
#  2   wtd_mean_atomic_mass             21263 non-null  float64
#  3   gmean_atomic_mass                21263 non-null  float64
#  4   wtd_gmean_atomic_mass            21263 non-null  float64
#  5   entropy_atomic_mass              21263 non-null  float64
#  6   wtd_entropy_atomic_mass          21263 non-null  float64
#  7   range_atomic_mass                21263 non-null  float64
#  8   wtd_range_atomic_mass            21263 non-null  float64
#  9   std_atomic_mass                  21263 non-null  float64
#  10  wtd_std_atomic_mass              21263 non-null  float64
# ...

# %%
df.describe()
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# count        21263.000000      21263.000000          21263.000000
# mean             4.115224         87.557631             72.988310
# std              1.439295         29.676497             33.490406
# min              1.000000          6.941000              6.423452
# 25%              3.000000         72.458076             52.143839
# 50%              4.000000         84.922750             60.696571
# 75%              5.000000        100.404410             86.103540
# max              9.000000        208.980400            208.980400
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# count       21263.000000           21263.000000         21263.000000
# mean           71.290627              58.539916             1.165608
# std            31.030272              36.651067             0.364930
# min             5.320573               1.960849             0.000000
# ...

# %% [markdown]
# ### Messing around with plots

# %%
# Common imports
import numpy as np
import os
# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
save_fig("attribute_histogram_plots")
plt.show()
# Out:
# Saving figure attribute_histogram_plots

# %% [markdown]
# #### Wow thats a lot of plots

# %%
df["critical_temp"]
# Out:
# 0         29.00
# 1         26.00
# 2         19.00
# 3         22.00
# 4         23.00
#           ...
# 21258      2.44
# 21259    122.10
# 21260      1.98
# 21261      1.84
# 21262     12.80
# Name: critical_temp, Length: 21262, dtype: float64

# %% [markdown]
# ## Lets mess around with the data

# %%
crit_temp = df["critical_temp"]

# %%
crit_temp = pd.Series(crit_temp)

# %%
crit_temp
# Out:
# 0         29.00
# 1         26.00
# 2         19.00
# 3         22.00
# 4         23.00
#           ...
# 21258      2.44
# 21259    122.10
# 21260      1.98
# 21261      1.84
# 21262     12.80
# Name: critical_temp, Length: 21262, dtype: float64

# %%
del df["critical_temp"]

# %%
df
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                       4         88.944468             57.862692
# 1                       5         92.729214             58.518416
# 2                       4         88.944468             57.885242
# 3                       4         88.944468             57.873967
# 4                       4         88.944468             57.840143
# ...                   ...               ...                   ...
# 21258                   4        106.957877             53.095769
# 21259                   5         92.266740             49.021367
# 21260                   2         99.663190             95.609104
# 21261                   2         99.663190             97.095602
# 21262                   3         87.468333             86.858500
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0              66.361592              36.116612             1.181795
# ...

# %%
crit_temp_cat, bins = pd.cut(crit_temp, bins=10, labels=range(10), retbins=True)

# %%
print(crit_temp_cat.value_counts())
# Out:
# 0    9180
# 1    3028
# 2    2145
# 5    1898
# 6    1892
# 4    1195
# 3    1158
# 7     424
# 8     238
# 9     104
# Name: critical_temp, dtype: int64

# %%
crit_temp_cat
# Out:
# 0        2
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 21258    0
# 21259    8
# 21260    0
# 21261    0
# 21262    0
# Name: critical_temp, Length: 21262, dtype: category
# Categories (10, int64): [0 < 1 < 2 < 3 ... 6 < 7 < 8 < 9]

# %% [raw]
# Ok The smallest bin needs to be at least 2, Thsi gives me 2 options:
#
# 1 - Delete the extreme datapoint
# 2 - Scale down the data

# %% [markdown]
# ## Ok lets delete the datapoint

# %%
values = df[df["critical_temp"].astype(str).str.contains("185")]

# %%
values
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 11672                   2            68.358               94.7898
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 11672          52.269966              82.753462             0.468006
#
#        wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 11672                 0.202273             88.106                85.0678
#
#        std_atomic_mass  ...  wtd_mean_Valence  gmean_Valence  \
# 11672           44.053  ...               2.0            2.0
#
#        wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 11672                2.0         0.693147             0.500402              0
#
#        wtd_range_Valence  std_Valence  wtd_std_Valence  critical_temp
# 11672                1.2          0.0              0.0          0.185
#
# [1 rows x 82 columns]

# %%
df = df.drop(20573)

# %%
df.describe()
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# count        21262.000000      21262.000000          21262.000000
# mean             4.115323         87.560971             72.991209
# std              1.439255         29.673198             33.488527
# min              1.000000          6.941000              6.423452
# 25%              3.000000         72.458076             52.144276
# 50%              4.000000         84.922750             60.697414
# 75%              5.000000        100.404410             86.103540
# max              9.000000        208.980400            208.980400
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# count       21262.000000           21262.000000         21262.000000
# mean           71.293713              58.542519             1.165656
# std            31.027739              36.649963             0.364871
# min             5.320573               1.960849             0.000000
# ...

# %% [markdown]
# # Break

# %%
df["critical_temp"]
# Out:
# 0         29.00
# 1         26.00
# 2         19.00
# 3         22.00
# 4         23.00
#           ...
# 21258      2.44
# 21259    122.10
# 21260      1.98
# 21261      1.84
# 21262     12.80
# Name: critical_temp, Length: 21263, dtype: float64

# %% [markdown]
# ## Lets do startified split

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.33, random_state=rng)

# %%
for train_index, test_index in split.split(df, crit_temp_cat):
    strat_train_set = df.loc[train_index]
    strat_y_train = crit_temp_cat.loc[train_index]
    strat_test_set = df.loc[test_index]
    strat_y_test = crit_temp_cat.loc[test_index]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 for train_index, test_index in split.split(df, crit_temp_cat):
# ----> 2     strat_train_set = df.loc[train_index]
#       3     strat_y_train = crit_temp_cat.loc[train_index]
#       4     strat_test_set = df.loc[test_index]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# ...
